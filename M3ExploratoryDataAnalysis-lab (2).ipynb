# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
df['ConvertedComp'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
df['ConvertedComp'].plot(kind='hist')

plt.title=('Histogram of ConvertedComp')

plt.xlabel('ConvertedComp')

plt.ylabel('Count')

plt.show()

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
med=df['ConvertedComp'].median()
print("The Median: ", med)
# Out:
# The Median:  57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df['Gender'].tolist().count('Man')
# Out:
# 10480

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df['Gender'].tolist().count('Woman')
# Out:
# 731

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df["Age"].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
df["Age"].plot(kind="hist",bins=15)
plt.xlabel('Age')
plt.show()

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
df["ConvertedComp"].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
Q1= df["ConvertedComp"].quantile(0.25)
Q3= df["ConvertedComp"].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
print("Upper Bounds :", Q3+(1.5*IQR))
print("Lower Bounds :", Q1+(1.5*IQR))
# Out:
# Upper Bounds : 209698.0
# Lower Bounds : 136566.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
outliers = df[(df["ConvertedComp"] < (Q1 - 1.5 * IQR)) | (df["ConvertedComp"] > (Q3 + 1.5 * IQR))]["ConvertedComp"]
len(outliers)
# Out:
# 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
new_clean_df = df[(df['ConvertedComp'] <= Q3+(1.5*IQR)) & (df['ConvertedComp'] >= Q1+(1.5*IQR))]
new_clean_df.head(5)
# Out:
#      Respondent                                         MainBranch Hobbyist  \
# 15           39                     I am a developer by profession      Yes
# 140         308                     I am a developer by profession      Yes
# 143         312                     I am a developer by profession       No
# 147         321                     I am a developer by profession      Yes
# 174         383  I am not primarily a developer, but I write co...      Yes
#
#                  OpenSourcer  \
# 15   Less than once per year
# 140                    Never
# 143                    Never
# 147                    Never
# 174                    Never
#
#                                             OpenSource          Employment  \
# 15   The quality of OSS and closed source software ...  Employed full-time
# 140  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 143  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 147  The quality of OSS and closed source software ...  Employed full-time
# 174  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#            Country         Student  \
# 15   United States              No
# 140  United States              No
# 143  United States              No
# 147  United States  Yes, part-time
# 174  United States              No
#
#                                                EdLevel  \
# 15            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 140        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 143        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 147  Some college/university study without earning ...
# 174        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                         UndergradMajor  ...  \
# 15   Computer science, computer engineering, or sof...  ...
# 140  Computer science, computer engineering, or sof...  ...
# 143                          Mathematics or statistics  ...
# 147  Another engineering discipline (ex. civil, ele...  ...
# 174  Information systems, information technology, o...  ...
#
#                                 WelcomeChange  \
# 15   Somewhat less welcome now than last year
# 140   Just as welcome now as I felt last year
# 143  Somewhat more welcome now than last year
# 147   Just as welcome now as I felt last year
# 174   Just as welcome now as I felt last year
#
#                                           SONewContent   Age Gender Trans  \
# 15           Tech articles written by other developers  42.0    Man    No
# 140                                                NaN  36.0  Woman    No
# 143          Tech articles written by other developers  31.0    Man    No
# 147                                                NaN  32.0  Woman    No
# 174  Tech articles written by other developers;Tech...  38.0    Man    No
#
#                    Sexuality                     Ethnicity Dependents  \
# 15                  Bisexual  White or of European descent         No
# 140  Straight / Heterosexual  White or of European descent         No
# 143  Straight / Heterosexual  White or of European descent         No
# 147  Straight / Heterosexual                    East Asian         No
# 174  Straight / Heterosexual  White or of European descent        Yes
#
#               SurveyLength SurveyEase
# 15   Appropriate in length       Easy
# 140  Appropriate in length       Easy
# 143  Appropriate in length       Easy
# 147                    NaN        NaN
# 174  Appropriate in length       Easy
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df.corr()["Age"]
# Out:
# Respondent       0.004041
# CompTotal        0.006970
# ConvertedComp    0.105386
# WorkWeekHrs      0.036518
# CodeRevHrs      -0.020469
# Age              1.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
